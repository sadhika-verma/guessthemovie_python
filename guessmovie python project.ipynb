# %% [markdown]
# #### Final code:

# %%
#Guess the movie from the emoji sequence
from tkinter import * 
from tkinter import messagebox 
import emoji
import random

#creating interface window
root = Tk()                                           #root is the name of our source window       
root.title("Guess The Movie from Emoji")              #function used to change title of window

#global variables 
score = 0             #to calculate score
answers = ["rockstar","ready","kill dil","good news","teen patti","dishoom","abcd 2","garam masala","student of the year","saath khoon maaf"]

#function to print CORRECT answer result

def correctanswerprint():
    global score
    mylabel = Label(root, text=emoji.emojize(":cherry_blossom::cherry_blossom::cherry_blossom::cherry_blossom::cherry_blossom::cherry_blossom::cherry_blossom:"),font=('times new roman',20,'bold'),fg="#F06292")
    mylabel.grid(row=26,column=0)
    finish_label = Label(root, text = "Your answer was CORRECT!",fg="#F44336",font=('times new roman',20,'bold'))
    finish_label.grid(row=27,column=0)
    score+=1
    score_label = Label(root, text = "Your score is "+ str(score) ,fg="#4CAF50",font=('times new roman',20,'bold'))
    score_label.grid(row=28,column=0)  
    
#function to CHECK ANSWER 

def check(my):
    if(my==answers[0] or my==answers[9] or my==answers[1] or my==answers[2] or my==answers[3] or my==answers[4] or my==answers[5] or my==answers[6] or my==answers[7] or my==answers[8]):
        correctanswerprint()
    else:
        finish_label = Label(root, text = "Your answer was INCORRECT! GAME OVER!",fg="#EC407A",font=('times new roman',20,'bold'))
        finish_label.grid(row=27,column=0)
        score_label = Label(root, text = "Your score is "+ str(score) ,fg="#4CAF50",font=('times new roman',20,'bold'))
        score_label.grid(row=28,column=0)  
    
#function that runs the game 

def StartGame():
        break_no_label = Label(root, text = "___________________________________________________", fg="#C2185B",font=('times new roman',20,'bold'))
        break_no_label.grid(row=8,column=0)
        break_no_label1 = Label(root, text = "___________________________________________________", fg="#C2185B",font=('times new roman',20,'bold'))
        break_no_label1.grid(row=30,column=0)
        question_no_label = Label(root, text = "𝕼𝖚𝖊𝖘𝖙𝖎𝖔𝖓:",font=('times new roman',25,'bold'))
        question_no_label.grid(row=10,column=0)
        i = random.randint(0,9)          #generating random integer number between 0-9
        if i==0:
            #displaying question 1 
            question_label = Label(root, text = "   🎸⭐  ", font=('times new roman',60,'bold'), bg="#FFCC80", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry widget
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==1:
            #displaying question 2        
            question_label = Label(root, text = "  🛑      🇩 ", font=('times new roman',60,'bold'), bg="#F44336", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==2:
            #displaying question 3
            question_label = Label(root, text = " 🔪  ♥️", font=('times new roman',60,'bold'), bg="#F8BBD0", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==3:
            #displaying question 4
            question_label = Label(root, text = " 👍     📰 ", font=('times new roman',60,'bold'), bg="#CFD8DC", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==4:
            #displaying question 5
            question_label = Label(root, text = " 🍁🍁🍁 ", font=('times new roman',60,'bold'), bg="#EF5350", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==5:
            #displaying question 6
            question_label = Label(root, text = "      👊     ", font=('times new roman',60,'bold'), bg="#FFCCBC", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==6:
            #displaying question 7
            question_label = Label(root, text = " 🆎💿✌ ", font=('times new roman',60,'bold'), bg="#FFF59D", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==7:
            #displaying question 8
            question_label = Label(root, text = "  🔥 🌶️", font=('times new roman',58,'bold'), bg="#E57373", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==8:
            #displaying question 9
            question_label = Label(root, text = " 🎓📴 👂 ", font=('times new roman',60,'bold'), bg="#F5CBA7", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
        if i==9:
            #displaying question 10
            question_label = Label(root, text = " 7 🔪 🙏 ", font=('times new roman',60,'bold'), bg="#C5CAE9", fg="black")
            question_label.grid(row=12,column=0)
            e = Entry(root, bg="#D1C4E9", fg="black", font=('times new roman',20,'bold'))    #making answer entry tag
            e.grid(row=15,column=0, padx=10, pady=10)
            answer_b= Button(root,text ="<<Check answer>>",command= lambda: check(e.get()),font=('times new roman',15,'bold'), bg="#BBDEFB", fg="black")
            answer_b.grid(row=20,column=0)
            
#function to go to next level

def NextLevel():
    question_label = Label(root, text = "                      ", font=('times new roman',60,'bold'))
    question_label.grid(row=12,column=0)
    finish_label = Label(root, text = "                                                                                  ",fg="#EC407A",font=('times new roman',20,'bold'))
    finish_label.grid(row=27,column=0)
    StartGame()
    
#MAIN PART OF THE CODE 

root.geometry("770x700")      #sets window size

#defining labels

label00=Label(root, text = "»»»          GUESS THE MOVIE FROM THE EMOJI           «««",fg="#B03A2E",font=('times new roman',20,'bold'))
label0=Label(root, text = "»» Rules for the game:",fg="#566573",font=('times new roman',16,'bold'))
label1=Label(root, text = "»» There will be one round",fg="#566573",font=('times new roman',16,'italic'))
label2=Label(root, text = "»» You have ONE chance to answer the question!",fg="#566573",font=('times new roman',16,'italic'))
label3=Label(root, text = "»» Game ends after you put in a wrong answer. Click on \"next level\" to move to next",fg="#566573",font=('times new roman',16,'italic'))
label4=Label(root, text = "CLICK START WHEN YOU ARE READY!",fg="#E74C3C",font=('times new roman',16,'bold'))

#positioning labels

label00.grid(row=0,column=0)
label0.grid(row=1,column=0,sticky=W)
label1.grid(row=2,column=0,sticky=W)
label2.grid(row=3,column=0,sticky=W)
label3.grid(row=3,column=0,sticky=W)
label4.grid(row=4,column=0)

#making start and restart button

button1 = Button(root, text="ＳＴＡＲＴ", padx=47, pady=5, command= StartGame, font=('times new roman',10),bg="#82E0AA",fg="black")
button2 = Button(root, text="ＮＥＸＴ ＬＥＶＥＬ", padx=20, pady=5, command= NextLevel, font=('times new roman',10),bg="#F5B7B1",fg="black")

#positioning start and restart button
button1.grid(row=6,column=0)
button2.grid(row=7,column=0)

root.mainloop()   #most important statement it tells python to run the tkinter event loop it runs until the user closes the window

# %%
#copy of list used
questions = ["🎸⭐", "🔳", "🔪♥️", "🤜🏼💥", "👍🏼📰", "🛑🇩", "🙋💖🗝️👍", "👊", "🆎💿✌🏼", "3️⃣🍁", "🎓📴👂", "🔥🌶️", "🚶🚶", "☝🏻👉🏼🐯", "❤️💓✌🏼", "7️⃣🔪🙏🏼"]
questions
# Out:
# ['🎸⭐',
#  '🔳',
#  '🔪♥️',
#  '🤜🏼💥',
#  '👍🏼📰',
#  '🛑🇩',
#  '🙋💖🗝️👍',
#  '👊',
#  '🆎💿✌🏼',
#  '3️⃣🍁',
#  '🎓📴👂',
#  '🔥🌶️',
#  '🚶🚶',
#  '☝🏻👉🏼🐯',
#  '❤️💓✌🏼',
#  '7️⃣🔪🙏🏼']

# %% [markdown]
# #### LIST OF ALL THE MOVIES USED IN CODE:
#
# Rockstar: 🎸⭐
#
# Pink: 🔳
#
# Kill Dil: 🔪♥️
#
# Force: 🤜🏼💥
#
# Good News: 👍🏼📰
#
# Ready: 🛑🇩
#
# Maine Pyaar Kiya: 🙋💖🗝️👍
#
# Dishoom: 👊
#
# ABCD 2: 🆎💿✌🏼
#
# Teen Patti: 3️⃣🍁
#
# Student of the Year: 🎓📴👂
#
# Garam Masala: 🔥🌶️
#
# Chalte chalte: 🚶🚶
#
# Ek Tha Tiger: ☝🏻👉🏼🐯
#
# Dil Dhadakne Do: ❤️💓✌
#
# Saath Khoon Maaf: 7️⃣🔪🙏
